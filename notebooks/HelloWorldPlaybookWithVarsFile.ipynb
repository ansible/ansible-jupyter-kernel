# %%
#ansible.cfg
[defaults]
host_key_checking=False

# %%
#inventory
[all]
localhost

# %%
#vars example_vars
message: hello vars

# %%
#play
name: hello world
hosts: localhost
gather_facts: false
vars_files:
    - example_vars

# %%
#task
debug:
 msg: "{{message}}"
# Out:
# TASK [debug] *******************************************************************
# ok: [localhost] => {
#     "msg": "hello vars"
# }
